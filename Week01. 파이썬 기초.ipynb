# %% [markdown]
# <a href="https://colab.research.google.com/github/kizoey/KUCC_NLP_DL_Session/blob/main/Week01.%20%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EA%B8%B0%EC%B4%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 산술연산**

# %%
1 - 2
# Out:
# -1

# %%
4 * 5
# Out:
# 20

# %%
7 / 5
# Out:
# 1.4

# %%
3 ** 2
# Out:
# 9

# %% [markdown]
# # **2. 자료형**

# %%
type(10)
# Out:
# int

# %%
type(2.718)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %% [markdown]
# # **3. 변수**

# %%
x = 10
print(x)
# Out:
# 10

# %%
x = 100
print(x)
# Out:
# 100

# %%
y = 3.14
x * y
# Out:
# 314.0

# %%
type(x * y)
# Out:
# float

# %% [markdown]
# # **4. 리스트**

# %%
a = [1, 2, 3, 4, 5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(a)
# Out:
# 5

# %%
a[0]
# Out:
# 1

# %%
a[4]
# Out:
# 5

# %%
a[4] = 99
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %%
a[1:3]
# Out:
# [2, 3]

# %%
a[1:]
# Out:
# [2, 3, 4, 99]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[:-1]
# Out:
# [1, 2, 3, 4]

# %%
a[:-2]
# Out:
# [1, 2, 3]

# %% [markdown]
# # **5. 딕셔너리**

# %%
me = {'height':180}
me['height']
# Out:
# 180

# %%
me['weight'] = 70
print(me)
# Out:
# {'height': 180, 'weight': 70}

# %% [markdown]
# # 6. **Bool**

# %%
hungry = True
sleepy = False
type(hungry)
# Out:
# bool

# %%
not hungry
# Out:
# False

# %%
hungry and sleepy
# Out:
# False

# %%
hungry or sleepy
# Out:
# True

# %% [markdown]
# # 7. **if문**

# %%
hungry = True
if hungry:
  print("I'm hungry")
# Out:
# I'm hungry

# %%
hungry = False
if hungry:
  print("I'm hungry")
else:
  print("I'm not hungry")
# Out:
# I'm not hungry

# %% [markdown]
# # 8. **For문**

# %%
for i in [1, 2, 3]:
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# # 9. **함수**

# %%
def hello():
  print("Hello World!")

hello()
# Out:
# Hello World!

# %%
def hello(object):
  print("Hello" + object + "!")

hello("cat")
# Out:
# Hellocat!

# %% [markdown]
# # 10. **클래스**

# %%
class Man:
  def __init__(self, name):
    self.name = name
    print("Initialized!")

  def hello(self):
    print("Hello " + self.name + "!")

  def goodbye(self):
    print("Good-bye " + self.name + "!")

m = Man("David")
m.hello()
m.goodbye()
# Out:
# Initialized!
# Hello David!
# Good-bye David!

# %% [markdown]
# # **11. Numpy**

# %%
import numpy as np

# %%
x = np.array([1.0, 2.0, 3.0])
print(x)
type(x)
# Out:
# [1. 2. 3.]
# numpy.ndarray

# %% [markdown]
# # 12. **N차원 배열**

# %%
A = np.array([[1, 2], [3, 4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
print(A.shape)
# Out:
# (2, 2)

# %%
print(A.dtype)
# Out:
# int64

# %% [markdown]
# # **13. 산술 연산**

# %%
x = np.array([1.0, 2.0, 3.0])
y = np.array([2.0, 4.0, 6.0])
print(x + y)
print(x - y)
print(x * y)
print(x / y)
# Out:
# [3. 6. 9.]
# [-1. -2. -3.]
# [ 2.  8. 18.]
# [0.5 0.5 0.5]

# %%
x = np.array([1.0, 2.0, 3.0])
x / 2.0
# Out:
# array([0.5, 1. , 1.5])

# %% [markdown]
# # **14. 원소 접근**

# %%
X = np.array([[51, 55], [14, 19], [0, 4]])
print(X)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]

# %%
X[0]
# Out:
# array([51, 55])

# %%
X[0][1]
# Out:
# 55

# %%
for row in X:
  print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %% [markdown]
# # **15. 평탄화**

# %%
X = X.flatten()
print(X)
X[np.array([0, 2, 4])]
# Out:
# [51 55 14 19  0  4]
# array([51, 14,  0])
